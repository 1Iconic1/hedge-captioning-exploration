# %% [markdown]
# # Abstention Testing
# Because VLMs can vary in their responses, this notebook checks how consistently correct or incorrect VLMs are in identifying products

# %%
import sys

sys.path.append("../../")

import os
import json

import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)
import torch
import spacy  # make sure to run python -m spacy download en_core_web_sm

from openai import OpenAI
from transformers import MllamaForConditionalGeneration, AutoProcessor, GenerationConfig
from transformers import AutoModelForCausalLM, AutoProcessor, GenerationConfig
from PIL import Image
from selfcheckgpt.modeling_selfcheck import SelfCheckNLI, SelfCheckBERTScore
from tqdm.notebook import tqdm

# %%
from scripts.constants import get_prompt

# %%
# setup pytorch
os.environ["CUDA_VISIBLE_DEVICES"] = "0"  # for multi-GPU systems, force single GPU
if torch.cuda.is_available():
    device_map = "cuda:0"  # force single, first GPU
    device_type = "cuda"
    torch_dtype = "auto"
elif torch.backends.mps.is_available():
    device_map = "auto"
    device_type = "mps"
    torch_dtype = torch.bfloat16
else:
    device_map = "auto"
    device_type = "cpu"
    torch_dtype = torch.bfloat16
print(f"Using device: {device_type}")
# Out:
# Using device: mps

# %%
# Load English tokenizer, tagger, parser and NER
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# ## Constants

# %%
MODEL_NAMES = {
    "gpt-4o-2024-08-06": "gpt4o",
    "Llama-3.2-11B-Vision-Instruct": "llama",
    "Molmo-7B-O-0924": "molmo",
}

# initialize openai client
openai_client = OpenAI()
openai_client.api_key = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# ## Helper functions to generate samples from model

# %%
def gpt4o_sampler_wrapper(row):
    image_url = row["vizwiz_url"]
    return generate_gpt4o_captions(image_url, openai_client, get_prompt(), count=5)


def generate_gpt4o_captions(
    image_url,
    openai_client,
    prompt,
    model_name="gpt-4o-2024-08-06",
    temperature=1.0,
    count=1,
):
    """
    Generates a caption for an image.

    Inputs:
    - image_url (str): url of image to caption.
    - prompt (str): prompt to use for captioning.
    - temperature (float; optional): temperature setting for model, greater than 0. Defaults to 1.0; lower values are more deterministic.
    - count (int; optional): how many samples should be generated

    Output:
    - (list of str): captions for image.
    """
    output = []
    for i in range(count):
        response = openai_client.responses.create(
            model=model_name,
            input=[
                {
                    "role": "system",
                    "content": [
                        {
                            "type": "input_text",
                            "text": prompt,
                        }
                    ],
                },
                {
                    "role": "user",
                    "content": [
                        {
                            "type": "input_image",
                            "image_url": image_url,
                        }
                    ],
                },
            ],
            text={"format": {"type": "text"}},
            reasoning={},
            tools=[],
            temperature=temperature,
            max_output_tokens=300,
            top_p=1,
            store=False,
        )

        if response.output_text is not None:
            output.append(response.output_text)
        else:
            output.append("")

    return output

# %%
def llama_sampler_wrapper(row):
    image_file = os.path.join("../data/caption-dataset/train", row["file_name"])
    image_object = Image.open(image_file)
    return generate_llama_captions(
        image_object, model, processor, get_prompt(), do_sample=True, count=5
    )


def generate_llama_captions(
    image_object, model, processor, prompt, temperature=1.0, do_sample=False, count=1
):
    """
    Generates a caption for an image.

    Inputs:
    - image_object (pil Image): image to caption.
    - model (torch model): loaded model to use for captioning.
    - processor (torch processor): loaded processor for pre-processing inputs.
    - temperature (float; optional): temperature setting for model, greater than 0. Defaults to 1.0; lower values are more deterministic.
    - do_sample (boolean; optional): whether model should sample probabilities. Defaults to False -- greedy decoding.

    Output:
    - (str): caption for image.
    """
    output = []
    for i in range(count):
        # process the image and text
        messages = [
            {"role": "system", "content": prompt},
            {
                "role": "user",
                "content": [
                    {"type": "image"},
                ],
            },
        ]

        input_text = processor.apply_chat_template(messages, add_generation_prompt=True)
        inputs = processor(
            image_object, input_text, add_special_tokens=False, return_tensors="pt"
        ).to(model.device)

        # generate output; maximum 300 new tokens; stop generation when <|endoftext|> is generated
        model_output = model.generate(
            **inputs,
            generation_config=GenerationConfig(
                max_new_tokens=300,
                stop_strings="<|endoftext|>",
                use_cache=True,
                temperature=temperature,
                do_sample=do_sample,
            ),
            tokenizer=processor.tokenizer,
        )

        # only get generated tokens; decode them to text
        generated_tokens = model_output[0, inputs["input_ids"].size(1) :]
        generated_text = processor.tokenizer.decode(
            generated_tokens, skip_special_tokens=True
        )

        output.append(generated_text.strip())
    return output

# %%
def molmo_sampler_wrapper(row):
    image_file = os.path.join("../data/caption-dataset/train", row["file_name"])
    image_object = Image.open(image_file)
    return generate_molmo_captions(
        image_object, model, processor, get_prompt(), do_sample=True, count=5
    )


def generate_molmo_captions(
    image_object, model, processor, prompt, temperature=1.0, do_sample=False, count=1
):
    """
    Generates a caption for an image.

    Inputs:
    - image_object (pil Image): image to caption.
    - model (torch model): loaded model to use for captioning.
    - processor (torch processor): loaded processor for pre-processing inputs.
    - temperature (float; optional): temperature setting for model, greater than 0. Defaults to 1.0; lower values are more deterministic.
    - do_sample (boolean; optional): whether model should sample probabilities. Defaults to False -- greedy decoding.

    Output:
    - (str): caption for image.
    """
    output = []
    for i in range(count):
        # process the image and text
        inputs = processor.process(
            images=[image_object],
            text=prompt,
        )

        # move inputs to the correct device and make a batch of size 1
        inputs = {k: v.to(model.device).unsqueeze(0) for k, v in inputs.items()}

        # generate output; maximum 300 new tokens; stop generation when <|endoftext|> is generated
        def generate_output():
            return model.generate_from_batch(
                inputs,
                GenerationConfig(max_new_tokens=300, stop_strings="<|endoftext|>"),
                tokenizer=processor.tokenizer,
                use_cache=True,
                temperature=temperature,
                do_sample=do_sample,
            )

        model_output = None
        if device_type == "cuda":
            model_output = generate_output()
        else:
            with torch.autocast(
                device_type=device_type, enabled=True, dtype=torch.bfloat16
            ):
                model_output = generate_output()

        # only get generated tokens; decode them to text
        generated_tokens = model_output[0, inputs["input_ids"].size(1) :]
        generated_text = processor.tokenizer.decode(
            generated_tokens, skip_special_tokens=True
        )

        output.append(generated_text.strip())
    return output

# %% [markdown]
# ## Load data

# %%
evaluated_captions_data = json.load(
    open(
        "../data/study-2-output/final-evaluated-captions/low-quality_evaluation_5432-images_2025-04-11_03-31_merged.json"
    )
)

print(f"Length of evaluated captions: {len(evaluated_captions_data)}")
# print(json.dumps(evaluated_captions_data[0], indent=4))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 evaluated_captions_data = json.load(
# ----> 2     open(
#       3         "../data/study-2-output/final-evaluated-captions/low-quality_evaluation_5432-images_2025-04-11_03-31_merged.json"
#       4     )
#       5 )
#       7 print(f"Length of evaluated captions: {len(evaluated_captions_data)}")
#       8 # print(json.dumps(evaluated_captions_data[0], indent=4))
#
# File ~/.local/share/virtualenvs/local-blurred-captioning-exploration-4LZKhcfn/lib/python3.11/site-packages/IPython/core/interactiveshell.py:326, in _modified_open(file, *args, **kwargs)
#     319 if file in {0, 1, 2}:
#     320     raise ValueError(
#     321         f"IPython won't let you open fd={file} by default "
#     322         "as it is likely to crash IPython. If you know what you are doing, "
#     323         "you can use builtins' open."
#     324     )
# --> 326 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/study-2-output/final-evaluated-captions/low-quality_evaluation_5432-images_2025-04-11_03-31_merged.json'

# %%
target_images_dtypes = {
    "image_id": int,
    "file_name": str,
    "vizwiz_url": str,
    "image_preview": str,
    "INCLUDE because product": str,
    "EXCLUDE because not verifable": str,
    "EXCLUDE because Book/DVD/CD/magazine?": str,
    "text_detected": str,
    "unrecognizable": bool,
    "framing": bool,
    "blur": bool,
    "obbooluction": bool,
    "rotation": bool,
    "too dark": bool,
    "too bright": bool,
    "other": bool,
    "no issue": bool,
    "unrecognizable_orig": int,
    "framing_orig": int,
    "blur_orig": int,
    "obstruction_orig": int,
    "rotation_orig": int,
    "too dark_orig": int,
    "too bright_orig": int,
    "other": int,
    "no issue": int,
    "human_caption_0": str,
    "human_caption_1": str,
    "human_caption_2": str,
    "human_caption_3": str,
    "human_caption_4": str,
    "gpt-4o-2024-08-06_caption": str,
    "Llama-3.2-11B-Vision-Instruct_caption": str,
    "Molmo-7B-O-0924_caption": str,
    "general_notes": str,
    "gpt-4o-2024-08-06_notes": str,
    "Llama-3.2-11B-Vision-Instruct_notes": str,
    "Molmo-7B-O-0924_notes": str,
    "image_preview": str,
    "unable_to_verify": str,
    "gpt4o_code": str,
    "llama_code": str,
    "molmo_code": str,
    "notes": str,
    "double code notes": str,
    "double verified": str,
    "curved label": str,
    "text panel": str,
    "AMP_rotation": str,
    "XT_rotation": str,
}

annotations_df = pd.read_csv(
    "../study-analysis/study-2-product-analysis/annotated-data/final-annotated-images_1696-images_2025-04-15_15-00.csv",
    dtype=target_images_dtypes,
    keep_default_na=False,
)

print(f"Number of annotated images: {len(annotations_df)}")
print(
    f"Number of images that were verified: {len(annotations_df[annotations_df['unable_to_verify'] == ''])}"
)
print(annotations_df.columns)
annotations_df.tail()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 54
#       1 target_images_dtypes = {
#       2     "image_id": int,
#       3     "file_name": str,
#    (...)     51     "XT_rotation": str,
#      52 }
# ---> 54 annotations_df = pd.read_csv(
#      55     "../study-analysis/study-2-product-analysis/annotated-data/final-annotated-images_1696-images_2025-04-15_15-00.csv",
#      56     dtype=target_images_dtypes,
#      57     keep_default_na=False,
#      58 )
#      60 print(f"Number of annotated images: {len(annotations_df)}")
#      61 print(
#      62     f"Number of images that were verified: {len(annotations_df[annotations_df['unable_to_verify'] == ''])}"
#      63 )
#
# File ~/.local/share/virtualenvs/local-blurred-captioning-exploration-4LZKhcfn/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/.local/share/virtualenvs/local-blurred-captioning-exploration-4LZKhcfn/lib/python3.11/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/.local/share/virtualenvs/local-blurred-captioning-exploration-4LZKhcfn/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/.local/share/virtualenvs/local-blurred-captioning-exploration-4LZKhcfn/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/.local/share/virtualenvs/local-blurred-captioning-exploration-4LZKhcfn/lib/python3.11/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../study-analysis/study-2-product-analysis/annotated-data/final-annotated-images_1696-images_2025-04-15_15-00.csv'

# %% [markdown]
# ## Consistency Experiment -- 05-09-25
# This experiment aims to check the consistency of LLM-generated captions of data

# %% [markdown]
# ### Generate samples

# %%
all_correct_df = annotations_df[
    (annotations_df["unable_to_verify"] == "")
    & (annotations_df["gpt4o_code"] == "no")
    & (annotations_df["molmo_code"] == "no")
    & (annotations_df["llama_code"] == "no")
]
all_incorrect_df = annotations_df[
    (annotations_df["unable_to_verify"] == "")
    & (annotations_df["gpt4o_code"] == "yes")
    & (annotations_df["molmo_code"] == "yes")
    & (annotations_df["llama_code"] == "yes")
]

sample_size = 5
example_count = 100
sampled_data = pd.concat(
    [
        all_correct_df.sample(n=example_count, random_state=42),
        all_incorrect_df.sample(n=example_count, random_state=42),
    ]
)
print(len(sampled_data))
# Out:
# 200

# %%
# compute gpt4o samples
sampled_data[
    [
        "gpt4o_sample_1",
        "gpt4o_sample_2",
        "gpt4o_sample_3",
        "gpt4o_sample_4",
        "gpt4o_sample_5",
    ]
] = sampled_data.apply(gpt4o_sampler_wrapper, axis=1, result_type="expand")

# %%
# compute llama samples
model_name = "Llama-3.2-11B-Vision-Instruct"
model_id = "meta-llama/Llama-3.2-11B-Vision-Instruct"
model = MllamaForConditionalGeneration.from_pretrained(
    model_id,
    torch_dtype=torch.bfloat16,
    device_map=device_map,
)
processor = AutoProcessor.from_pretrained(model_id)

sampled_data[
    [
        "llama_sample_1",
        "llama_sample_2",
        "llama_sample_3",
        "llama_sample_4",
        "llama_sample_5",
    ]
] = sampled_data.apply(llama_sampler_wrapper, axis=1, result_type="expand")

# free memory after we're done
del model_name
del model_id
del model
del processor
torch.cuda.empty_cache()
# Out:
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
# compute molmo samples
model_name = "Molmo-7B-O-0924"
model_id = "allenai/Molmo-7B-O-0924"
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    trust_remote_code=True,
    torch_dtype=torch_dtype,
    device_map=device_map,
)
processor = AutoProcessor.from_pretrained(
    model_id,
    trust_remote_code=True,
    torch_dtype=torch_dtype,
    device_map=device_map,
)

sampled_data[
    [
        "molmo_sample_1",
        "molmo_sample_2",
        "molmo_sample_3",
        "molmo_sample_4",
        "molmo_sample_5",
    ]
] = sampled_data.apply(molmo_sampler_wrapper, axis=1, result_type="expand")

# free memory after we're done
del model_name
del model_id
del model
del processor
torch.cuda.empty_cache()
# Out:
# Loading checkpoint shards:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
# save data
sampled_data.to_csv(
    f"./sampled_data_{len(sampled_data)}-examples_{sample_size}-samples.csv",
    index=False,
)
sampled_data.head()
# Out:
#       image_id                  file_name  \
# 972      12307  VizWiz_train_00012307.jpg
# 1571      3462  VizWiz_train_00003462.jpg
# 679      13723  VizWiz_train_00013723.jpg
# 1316      3949  VizWiz_train_00003949.jpg
# 1228     17176  VizWiz_train_00017176.jpg
#
#                                              vizwiz_url image_preview  \
# 972   https://vizwiz.cs.colorado.edu/VizWiz_visualiz...
# 1571  https://vizwiz.cs.colorado.edu/VizWiz_visualiz...
# 679   https://vizwiz.cs.colorado.edu/VizWiz_visualiz...
# 1316  https://vizwiz.cs.colorado.edu/VizWiz_visualiz...
# 1228  https://vizwiz.cs.colorado.edu/VizWiz_visualiz...
#
#                                          human_captions   annotator  \
# 972   A very close up shot of a package that says Ve...  Anne Marie
# 1571  A colorful bag of lollipops for small children...
# 679   a white box of medication on a blue fabric sur...  Anne Marie
# 1316  appears to be a picture of meatballs and mozza...  Anne Marie
# 1228  A red and white box of Home Style Beef Goulash...  Anne Marie
#
#                                              notes unable_to_verify  \
# 972                                    venus razor
# 1571                          strawberry lollipops
# 679               medication expectorant walgreens
# 1316  meatball and mozzarella hot pocket / hot pie
# 1228                       home style beef goulash
#
#      double code notes double verified  \
# 972                                  x
# 1571                                 x
# 679                                  x
# 1316                                 x
# 1228                                 x
#
#                                           gpt4o_caption gpt4o_code  \
# 972   Text "Venus Breeze" is visible against a light...         no
# 1571  A package with a polka dot pattern in various ...         no
# 679   A white box with detailed text on its side, in...         no
# 1316  A red packaging box with white text reads "MEA...         no
# 1228  Label with text reading "Home Style Beef Goula...         no
#
#                                           llama_caption llama_code  \
# 972   The image appears to be a close-up of a produc...         no
# 1571  The image shows a white bag with multicolored ...         no
# 679   The image shows a white rectangular box with a...         no
# 1316  The image shows a red box of frozen meatballs ...         no
# 1228  The image shows a close-up of a white and red ...         no
#
#                                           molmo_caption molmo_code  \
# 972   The image shows a close-up of a product packag...         no
# 1571  The image shows a package of wipes. It has a w...         no
# 679   The image shows a white rectangular box, likel...         no
# 1316  The image shows a box of frozen food, specific...         no
# 1228  The image shows a partially visible food packa...         no
#
#      text_detected  unrecognizable_orig  framing_orig  blur_orig  \
# 972           True                    0             4          2
# 1571          True                    0             1          0
# 679           True                    0             2          0
# 1316          True                    0             3          4
# 1228          True                    1             4          4
#
#       obstruction_orig  rotation_orig  too_dark_orig  too_bright_orig  \
# 972                  0              2              0                0
# 1571                 0              4              1                0
# 679                  0              4              0                3
# 1316                 0              3              1                0
# 1228                 0              0              1                0
#
#       other_orig curved label text panel AMP_rotation XT_rotation  \
# 972            0                                    x           x
# 1571           0                       x            x           x
# 679            1                       x            x           x
# 1316           0                                    x           x
# 1228           0                                    x           x
#
#                                       expert_caption  unrecognizable  framing  \
# 972                                                            False     True
# 1571  A colorful bag of lollipops for small children           False    False
# 679                                                            False     True
# 1316                                                           False     True
# 1228                                                           False     True
#
#        blur  obstruction  rotation  too dark  too bright  other  \
# 972    True        False      True     False       False      0
# 1571  False        False      True     False       False      0
# 679   False        False      True     False        True      0
# 1316   True        False      True     False       False      0
# 1228   True        False      True     False       False      0
#
#                                          gpt4o_sample_1  \
# 972   The image shows part of a package with text "B...
# 1571  A package with a colorful polka dot design and...
# 679   A white rectangular box with printed text, inc...
# 1316  A red package featuring the text "12 MEATBALLS...
# 1228  The image shows a food package with the text "...
#
#                                          gpt4o_sample_2  \
# 972   Text "Venus Breeze" is visible on a teal and p...
# 1571  A package with a colorful polka dot pattern fe...
# 679   A rectangular white box with black text and a ...
# 1316  A product packaging with a red banner containi...
# 1228  A product package with visible text reads "HOM...
#
#                                          gpt4o_sample_3  \
# 972   The image contains the text "Venus Breeze" on ...
# 1571  A package with a pattern of colorful dots on a...
# 679   A box with printed information and a barcode o...
# 1316  A red package with white text reads "MEATBALLS...
# 1228  The image shows part of a package label. Visib...
#
#                                          gpt4o_sample_4  \
# 972   Text showing "Venus Breeze" on a blue and purp...
# 1571  A package with a colorful polka dot design in ...
# 679   A box with a barcode on the top and a section ...
# 1316  A red and yellow packaging for a product label...
# 1228  A package label with text stating "HOME STYLE ...
#
#                                          gpt4o_sample_5  \
# 972   The image displays a package with the words "V...
# 1571  Colorful polka dot packaging with a nutrition ...
# 679   A box on a blue surface with visible text incl...
# 1316  A red package with text reading "Meatballs & M...
# 1228  Partial text on a food package reads "HOME STY...
#
#                                          llama_sample_1  \
# 972   The image shows a close-up of a box featuring ...
# 1571  The image shows a white bag with polka dots in...
# 679   The object is a white box featuring a rectangu...
# 1316  The image appears to show a frozen food box fo...
# 1228  The image shows a label for a jar of beef goul...
#
#                                          llama_sample_2  \
# 972   The image appears to show part of the word "Zy...
# 1571  The product appears to be a bag of lollipops w...
# 679   The image appears to show a white rectangular ...
# 1316  The image appears to be a photograph of a red ...
# 1228  This image shows a plastic red and white packa...
#
#                                          llama_sample_3  \
# 972   The image depicts the partially visible logo f...
# 1571  The image shows a sealed plastic bag filled wi...
# 679   A white rectangular box with the top facing th...
# 1316  The image appears to be of a frozen food produ...
# 1228  The image shows a close-up of a package of gro...
#
#                                          llama_sample_4  \
# 972   The primary object is a blue rectangular objec...
# 1571  The image shows a package of strawberry lollip...
# 679   The object appears to be a white box containin...
# 1316  The image displays the top of a rectangular, r...
# 1228  The image shows a rectangular, light-colored c...
#
#                                          llama_sample_5  \
# 972   The image depicts a box with the word 'Zenni' ...
# 1571  The image appears to show a bag with vibrant c...
# 679   The image depicts a white box with a barcode o...
# 1316  The image shows a red box with white text read...
# 1228  The image shows a box of home-style beef goula...
#
#                                          molmo_sample_1  \
# 972   The image displays a small rectangular box, li...
# 1571  A pair of light blue athletic shorts with a ne...
# 679   The image shows a white rectangular box lying ...
# 1316  The image shows the edge of a red object, like...
# 1228  The image shows the lower right portion of a f...
#
#                                          molmo_sample_2  \
# 972   The image shows a blue, square-shaped book cov...
# 1571  The image depicts the bottom of a package or b...
# 679   The image shows the backside of a white box, l...
# 1316  The image shows the edge of a single-serve foo...
# 1228  A label for a ground beef product. It's a whit...
#
#                                          molmo_sample_3  \
# 972   The image depicts a wooden surface, likely a t...
# 1571  Ball-like package filled with a colorful, mult...
# 679   A rectangular white box is resting horizontall...
# 1316  The image shows a red, folded box of grocery p...
# 1228  A white and red package for ground beef, likel...
#
#                                          molmo_sample_4  \
# 972   The image shows a close-up of an ice cream bar...
# 1571  The image depicts a person wearing blue athlet...
# 679   A white box is upside down on a blue fabric. T...
# 1316  A red box containing Pepperidge Farm Milano co...
# 1228  The object is a box of ground beef product. It...
#
#                                          molmo_sample_5
# 972   The image depicts a blue packaging with a pink...
# 1571  The user is observing the back of a box of Tam...
# 679   The image shows an upside-down rectangular box...
# 1316  The image displays a red cardboard package for...
# 1228  The image shows a white package label. The pro...

# %% [markdown]
# ### Compute consistency
# Below, we test consistency in responses using [SelfCheckGPT](https://github.com/potsawee/selfcheckgpt). The paper offers 5 approaches for checking consistency:
# 1. BERTScore: finds the average BERTScore of ths i-th sentence with the most similar sentence from each sample. If information in a sentnece appears in many samples, one can assume that the information is factual.
# 2. Question Answering: generates multiple-choice questions over the main passage, which a separate question answering system can attempt to answer while conditioned on  the other sampled respones. If questions on consistent information are queried, the answering system should predict similar answers.
# 3. N-gram: idea is to use sampled responses to create a new langauge model that approximates the generating LLM. when N is large, the new model will converse to LLM resposnes. Practically, this is done by training a n-gram model using the samples and original passage. The final score is the average log-probability of each token in the original passage, as computed by the n-gram model.
# 4. Natural Language Inference (NLI): determins whether a hypothesis follows a premise, classified as entailment, neutral, or contradition. Score is defined as the average probability of contradition given the reference sentence across all sampled passages. The final score is the probability of contradiction for each sentence
# 5. LLM Prompting: uses an LLM to check if the i-th sentence in the passaage us supported by the sample for each sample. The final score is an average of how many sampeld sentences support the i-th sentence.
#
# Note that for any that split a passage into separate sentences, you'll get an array of scores for each sentence.
#
# The LLM prompting method was shown to be most effective, but NLI method is not significantly worse. Below, we use the NLI method since it's faster to compute and offers close enough accuracy.

# %%
def compute_consistency_nli(row, model_name, model):
    # get passage and samples
    passage = row[f"{model_name}_caption"]
    samples = [
        row[f"{model_name}_sample_1"],
        row[f"{model_name}_sample_2"],
        row[f"{model_name}_sample_3"],
        row[f"{model_name}_sample_4"],
        row[f"{model_name}_sample_5"],
    ]

    # get sentences for original passage
    sentences = [sent.text.strip() for sent in nlp(passage).sents]

    scores = model.predict(sentences=sentences, sampled_passages=samples)
    return sentences, scores


selfcheck_nli = SelfCheckNLI(device=device_type)
# Out:
# SelfCheck-NLI initialized to device cuda

# %%
sampled_consistency_df = sampled_data.copy(deep=True)
for model in ["gpt4o", "llama", "molmo"]:
    # create placeholder columns
    for i in range(0, 5):
        sampled_consistency_df[f"{model}_caption_sent-{i+1}"] = None
        sampled_consistency_df[f"{model}_nli_sent-{i+1}"] = np.nan
    sampled_consistency_df[f"{model}_nli_avg_contrad"] = np.nan

    # loop over each example and compute NLI P(contradiction)
    for index, row in tqdm(
        sampled_consistency_df.iterrows(), total=sampled_consistency_df.shape[0]
    ):
        # compute the probability of contradition for all sentences in the original caption, using
        sentences, scores = compute_consistency_nli(row, model, selfcheck_nli)

        # add sentences and contradiction score for the sentence
        for sent_index, sentence in enumerate(sentences):
            sampled_consistency_df.loc[
                index, f"{model}_caption_sent-{sent_index+1}"
            ] = sentence
        for score_index, score in enumerate(scores):
            sampled_consistency_df.loc[index, f"{model}_nli_sent-{score_index+1}"] = (
                float(score)
            )

        # add average
        sampled_consistency_df.loc[index, f"{model}_nli_avg_contrad"] = np.mean(scores)

    # remove extra columns without any sentences or scores
    sampled_consistency_df.dropna(axis=1, how="all", inplace=True)

# clear memory
del selfcheck_nli
torch.cuda.empty_cache()

# save file and print
sampled_consistency_df.to_csv(
    f"./sampled-data-consistency_{len(sampled_data)}-examples_{sample_size}-samples.csv",
    index=False,
)
sampled_consistency_df.head()
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
#       image_id                  file_name  \
# 972      12307  VizWiz_train_00012307.jpg
# 1571      3462  VizWiz_train_00003462.jpg
# 679      13723  VizWiz_train_00013723.jpg
# 1316      3949  VizWiz_train_00003949.jpg
# 1228     17176  VizWiz_train_00017176.jpg
#
#                                              vizwiz_url image_preview  \
# 972   https://vizwiz.cs.colorado.edu/VizWiz_visualiz...
# 1571  https://vizwiz.cs.colorado.edu/VizWiz_visualiz...
# 679   https://vizwiz.cs.colorado.edu/VizWiz_visualiz...
# 1316  https://vizwiz.cs.colorado.edu/VizWiz_visualiz...
# 1228  https://vizwiz.cs.colorado.edu/VizWiz_visualiz...
#
#                                          human_captions   annotator  \
# 972   A very close up shot of a package that says Ve...  Anne Marie
# 1571  A colorful bag of lollipops for small children...
# 679   a white box of medication on a blue fabric sur...  Anne Marie
# 1316  appears to be a picture of meatballs and mozza...  Anne Marie
# 1228  A red and white box of Home Style Beef Goulash...  Anne Marie
#
#                                              notes unable_to_verify  \
# 972                                    venus razor
# 1571                          strawberry lollipops
# 679               medication expectorant walgreens
# 1316  meatball and mozzarella hot pocket / hot pie
# 1228                       home style beef goulash
#
#      double code notes double verified  \
# 972                                  x
# 1571                                 x
# 679                                  x
# 1316                                 x
# 1228                                 x
#
#                                           gpt4o_caption gpt4o_code  \
# 972   Text "Venus Breeze" is visible against a light...         no
# 1571  A package with a polka dot pattern in various ...         no
# 679   A white box with detailed text on its side, in...         no
# 1316  A red packaging box with white text reads "MEA...         no
# 1228  Label with text reading "Home Style Beef Goula...         no
#
#                                           llama_caption llama_code  \
# 972   The image appears to be a close-up of a produc...         no
# 1571  The image shows a white bag with multicolored ...         no
# 679   The image shows a white rectangular box with a...         no
# 1316  The image shows a red box of frozen meatballs ...         no
# 1228  The image shows a close-up of a white and red ...         no
#
#                                           molmo_caption molmo_code  \
# 972   The image shows a close-up of a product packag...         no
# 1571  The image shows a package of wipes. It has a w...         no
# 679   The image shows a white rectangular box, likel...         no
# 1316  The image shows a box of frozen food, specific...         no
# 1228  The image shows a partially visible food packa...         no
#
#      text_detected  unrecognizable_orig  framing_orig  blur_orig  \
# 972           True                    0             4          2
# 1571          True                    0             1          0
# 679           True                    0             2          0
# 1316          True                    0             3          4
# 1228          True                    1             4          4
#
#       obstruction_orig  rotation_orig  too_dark_orig  too_bright_orig  \
# 972                  0              2              0                0
# 1571                 0              4              1                0
# 679                  0              4              0                3
# 1316                 0              3              1                0
# 1228                 0              0              1                0
#
#       other_orig curved label text panel AMP_rotation XT_rotation  \
# 972            0                                    x           x
# 1571           0                       x            x           x
# 679            1                       x            x           x
# 1316           0                                    x           x
# 1228           0                                    x           x
#
#                                       expert_caption  unrecognizable  framing  \
# 972                                                            False     True
# 1571  A colorful bag of lollipops for small children           False    False
# 679                                                            False     True
# 1316                                                           False     True
# 1228                                                           False     True
#
#        blur  obstruction  rotation  too dark  too bright  other  \
# 972    True        False      True     False       False      0
# 1571  False        False      True     False       False      0
# 679   False        False      True     False        True      0
# 1316   True        False      True     False       False      0
# 1228   True        False      True     False       False      0
#
#                                          gpt4o_sample_1  \
# 972   The image shows part of a package with text "B...
# 1571  A package with a colorful polka dot design and...
# 679   A white rectangular box with printed text, inc...
# 1316  A red package featuring the text "12 MEATBALLS...
# 1228  The image shows a food package with the text "...
#
#                                          gpt4o_sample_2  \
# 972   Text "Venus Breeze" is visible on a teal and p...
# 1571  A package with a colorful polka dot pattern fe...
# 679   A rectangular white box with black text and a ...
# 1316  A product packaging with a red banner containi...
# 1228  A product package with visible text reads "HOM...
#
#                                          gpt4o_sample_3  \
# 972   The image contains the text "Venus Breeze" on ...
# 1571  A package with a pattern of colorful dots on a...
# 679   A box with printed information and a barcode o...
# 1316  A red package with white text reads "MEATBALLS...
# 1228  The image shows part of a package label. Visib...
#
#                                          gpt4o_sample_4  \
# 972   Text showing "Venus Breeze" on a blue and purp...
# 1571  A package with a colorful polka dot design in ...
# 679   A box with a barcode on the top and a section ...
# 1316  A red and yellow packaging for a product label...
# 1228  A package label with text stating "HOME STYLE ...
#
#                                          gpt4o_sample_5  \
# 972   The image displays a package with the words "V...
# 1571  Colorful polka dot packaging with a nutrition ...
# 679   A box on a blue surface with visible text incl...
# 1316  A red package with text reading "Meatballs & M...
# 1228  Partial text on a food package reads "HOME STY...
#
#                                          llama_sample_1  \
# 972   The image shows a close-up of a box featuring ...
# 1571  The image shows a white bag with polka dots in...
# 679   The object is a white box featuring a rectangu...
# 1316  The image appears to show a frozen food box fo...
# 1228  The image shows a label for a jar of beef goul...
#
#                                          llama_sample_2  \
# 972   The image appears to show part of the word "Zy...
# 1571  The product appears to be a bag of lollipops w...
# 679   The image appears to show a white rectangular ...
# 1316  The image appears to be a photograph of a red ...
# 1228  This image shows a plastic red and white packa...
#
#                                          llama_sample_3  \
# 972   The image depicts the partially visible logo f...
# 1571  The image shows a sealed plastic bag filled wi...
# 679   A white rectangular box with the top facing th...
# 1316  The image appears to be of a frozen food produ...
# 1228  The image shows a close-up of a package of gro...
#
#                                          llama_sample_4  \
# 972   The primary object is a blue rectangular objec...
# 1571  The image shows a package of strawberry lollip...
# 679   The object appears to be a white box containin...
# 1316  The image displays the top of a rectangular, r...
# 1228  The image shows a rectangular, light-colored c...
#
#                                          llama_sample_5  \
# 972   The image depicts a box with the word 'Zenni' ...
# 1571  The image appears to show a bag with vibrant c...
# 679   The image depicts a white box with a barcode o...
# 1316  The image shows a red box with white text read...
# 1228  The image shows a box of home-style beef goula...
#
#                                          molmo_sample_1  \
# 972   The image displays a small rectangular box, li...
# 1571  A pair of light blue athletic shorts with a ne...
# 679   The image shows a white rectangular box lying ...
# 1316  The image shows the edge of a red object, like...
# 1228  The image shows the lower right portion of a f...
#
#                                          molmo_sample_2  \
# 972   The image shows a blue, square-shaped book cov...
# 1571  The image depicts the bottom of a package or b...
# 679   The image shows the backside of a white box, l...
# 1316  The image shows the edge of a single-serve foo...
# 1228  A label for a ground beef product. It's a whit...
#
#                                          molmo_sample_3  \
# 972   The image depicts a wooden surface, likely a t...
# 1571  Ball-like package filled with a colorful, mult...
# 679   A rectangular white box is resting horizontall...
# 1316  The image shows a red, folded box of grocery p...
# 1228  A white and red package for ground beef, likel...
#
#                                          molmo_sample_4  \
# 972   The image shows a close-up of an ice cream bar...
# 1571  The image depicts a person wearing blue athlet...
# 679   A white box is upside down on a blue fabric. T...
# 1316  A red box containing Pepperidge Farm Milano co...
# 1228  The object is a box of ground beef product. It...
#
#                                          molmo_sample_5  \
# 972   The image depicts a blue packaging with a pink...
# 1571  The user is observing the back of a box of Tam...
# 679   The image shows an upside-down rectangular box...
# 1316  The image displays a red cardboard package for...
# 1228  The image shows a white package label. The pro...
#
#                                    gpt4o_caption_sent-1  gpt4o_nli_sent-1  \
# 972   Text "Venus Breeze" is visible against a light...          0.068755
# 1571  A package with a polka dot pattern in various ...          0.248454
# 679   A white box with detailed text on its side, in...          0.364978
# 1316  A red packaging box with white text reads "MEA...          0.073244
# 1228  Label with text reading "Home Style Beef Goula...          0.054986
#
#                                    gpt4o_caption_sent-2  gpt4o_nli_sent-2  \
# 972    The image appears to be a close-up of packaging.          0.264089
# 1571  There is a white label with nutrition facts an...          0.240949
# 679   There is a barcode and some numbers printed on...          0.342193
# 1316  The packaging mentions "12" and includes an im...          0.122873
# 1228  Additional text mentions "ground beef", "elbow...          0.001054
#
#      gpt4o_caption_sent-3  gpt4o_nli_sent-3 gpt4o_caption_sent-4  \
# 972                  None               NaN                 None
# 1571                 None               NaN                 None
# 679                  None               NaN                 None
# 1316                 None               NaN                 None
# 1228                 None               NaN                 None
#
#       gpt4o_nli_sent-4  gpt4o_nli_avg_contrad  \
# 972                NaN               0.166422
# 1571               NaN               0.244702
# 679                NaN               0.353586
# 1316               NaN               0.098058
# 1228               NaN               0.028020
#
#                                    llama_caption_sent-1  llama_nli_sent-1  \
# 972   The image appears to be a close-up of a produc...          0.393664
# 1571  The image shows a white bag with multicolored ...          0.378901
# 679   The image shows a white rectangular box with a...          0.660227
# 1316  The image shows a red box of frozen meatballs ...          0.930255
# 1228  The image shows a close-up of a white and red ...          0.443574
#
#                                    llama_caption_sent-2  llama_nli_sent-2  \
# 972   The background is a blue-green color with a pi...          0.532239
# 1571  The bag is made of a shiny material, possibly ...          0.827437
# 679                                                None               NaN
# 1316  The box features white text that reads "MEATBA...          0.924989
# 1228  The box has a red stripe on the left side and ...          0.875598
#
#      llama_caption_sent-3  llama_nli_sent-3 llama_caption_sent-4  \
# 972                  None               NaN                 None
# 1571                 None               NaN                 None
# 679                  None               NaN                 None
# 1316                 None               NaN                 None
# 1228                 None               NaN                 None
#
#       llama_nli_sent-4 llama_caption_sent-5  llama_nli_sent-5  \
# 972                NaN                 None               NaN
# 1571               NaN                 None               NaN
# 679                NaN                 None               NaN
# 1316               NaN                 None               NaN
# 1228               NaN                 None               NaN
#
#       llama_nli_avg_contrad  \
# 972                0.462952
# 1571               0.603169
# 679                0.660227
# 1316               0.927622
# 1228               0.659586
#
#                                    molmo_caption_sent-1  molmo_nli_sent-1  \
# 972   The image shows a close-up of a product packag...          0.659138
# 1571                The image shows a package of wipes.          0.979746
# 679   The image shows a white rectangular box, likel...          0.293056
# 1316  The image shows a box of frozen food, specific...          0.368442
# 1228  The image shows a partially visible food packa...          0.016550
#
#                                    molmo_caption_sent-2  molmo_nli_sent-2  \
# 972   The visible text reads "3VENUE BREE", which ap...          0.379306
# 1571  It has a white background with colorful polka ...          0.202595
# 679   The box has a barcode at the top and a large w...          0.978095
# 1316  The box is red with white text and a yellow nu...          0.559877
# 1228  The top left corner displays a circular logo w...          0.736998
#
#      molmo_caption_sent-3  molmo_nli_sent-3  molmo_nli_avg_contrad
# 972                  None               NaN               0.519222
# 1571                 None               NaN               0.591171
# 679                  None               NaN               0.635576
# 1316                 None               NaN               0.464160
# 1228                 None               NaN               0.376774

# %% [markdown]
# ### Summary Statistics

# %%
sampled_consistency_df.groupby(["gpt4o_code"])["gpt4o_nli_avg_contrad"].describe()
# Out:
#             count      mean       std       min       25%       50%       75%  \
# gpt4o_code
# no          100.0  0.317633  0.196882  0.007176  0.151667  0.303487  0.437047
# yes         100.0  0.308758  0.202405  0.001224  0.142871  0.303035  0.441471
#
#                  max
# gpt4o_code
# no          0.863079
# yes         0.874776

# %%
sampled_consistency_df.groupby(["llama_code"])["llama_nli_avg_contrad"].describe()
# Out:
#             count      mean       std       min       25%       50%       75%  \
# llama_code
# no          100.0  0.661629  0.200535  0.122736  0.546990  0.661515  0.809917
# yes         100.0  0.581768  0.189543  0.170037  0.445887  0.595260  0.709915
#
#                  max
# llama_code
# no          0.991641
# yes         0.920642

# %%
sampled_consistency_df.groupby(["molmo_code"])["molmo_nli_avg_contrad"].describe()
# Out:
#             count      mean       std       min       25%       50%       75%  \
# molmo_code
# no          100.0  0.619778  0.195174  0.073967  0.475850  0.649546  0.762703
# yes         100.0  0.509423  0.200216  0.072933  0.381612  0.477351  0.656998
#
#                  max
# molmo_code
# no          0.996195
# yes         0.968703

# %% [markdown]
# ### Statistics by image quality issue
# For now, just on blur, framing, and rotation.

# %% [markdown]
# #### GPT-4o

# %%
sampled_consistency_df.groupby(["gpt4o_code", "blur"])[
    "gpt4o_nli_avg_contrad"
].describe()
# Out:
#                   count      mean       std       min       25%       50%  \
# gpt4o_code blur
# no         False   34.0  0.282352  0.184947  0.037203  0.113085  0.269214
#            True    66.0  0.335808  0.201707  0.007176  0.166858  0.345942
# yes        False   57.0  0.298883  0.201423  0.001306  0.116690  0.294036
#            True    43.0  0.321849  0.205338  0.001224  0.182999  0.334669
#
#                        75%       max
# gpt4o_code blur
# no         False  0.390428  0.754639
#            True   0.441557  0.863079
# yes        False  0.443486  0.756985
#            True   0.438357  0.874776

# %%
sampled_consistency_df.groupby(["gpt4o_code", "framing"])[
    "gpt4o_nli_avg_contrad"
].describe()
# Out:
#                     count      mean       std       min       25%       50%  \
# gpt4o_code framing
# no         False     31.0  0.411803  0.212176  0.037203  0.228492  0.401518
#            True      69.0  0.275325  0.175252  0.007176  0.116234  0.282836
# yes        False     29.0  0.269778  0.195518  0.001224  0.099482  0.288663
#            True      71.0  0.324680  0.204359  0.001306  0.172432  0.338247
#
#                          75%       max
# gpt4o_code framing
# no         False    0.529016  0.863079
#            True     0.398499  0.684512
# yes        False    0.404620  0.768557
#            True     0.468009  0.874776

# %%
sampled_consistency_df.groupby(["gpt4o_code", "rotation"])[
    "gpt4o_nli_avg_contrad"
].describe()
# Out:
#                      count      mean       std       min       25%       50%  \
# gpt4o_code rotation
# no         False      52.0  0.331478  0.174620  0.037203  0.198543  0.346957
#            True       48.0  0.302635  0.219362  0.007176  0.125167  0.269789
# yes        False      72.0  0.306477  0.205881  0.001224  0.105955  0.303035
#            True       28.0  0.314623  0.196730  0.002953  0.202987  0.303642
#
#                           75%       max
# gpt4o_code rotation
# no         False     0.437047  0.735219
#            True      0.413259  0.863079
# yes        False     0.460814  0.874776
#            True      0.425091  0.768557

# %% [markdown]
# #### Molmo

# %%
sampled_consistency_df.groupby(["molmo_code", "blur"])[
    "molmo_nli_avg_contrad"
].describe()
# Out:
#                   count      mean       std       min       25%       50%  \
# molmo_code blur
# no         False   34.0  0.575511  0.188892  0.073967  0.483949  0.572702
#            True    66.0  0.642582  0.195834  0.135824  0.478299  0.684991
# yes        False   57.0  0.522982  0.188323  0.108125  0.390714  0.493907
#            True    43.0  0.491450  0.215920  0.072933  0.355789  0.476207
#
#                        75%       max
# molmo_code blur
# no         False  0.716403  0.970956
#            True   0.773800  0.996195
# yes        False  0.655514  0.904867
#            True   0.652762  0.968703

# %%
sampled_consistency_df.groupby(["molmo_code", "framing"])[
    "molmo_nli_avg_contrad"
].describe()
# Out:
#                     count      mean       std       min       25%       50%  \
# molmo_code framing
# no         False     31.0  0.667915  0.197345  0.135824  0.574108  0.704987
#            True      69.0  0.598151  0.191693  0.073967  0.464160  0.613227
# yes        False     29.0  0.475661  0.219697  0.072933  0.332644  0.426414
#            True      71.0  0.523214  0.191630  0.108125  0.412692  0.499711
#
#                          75%       max
# molmo_code framing
# no         False    0.816442  0.955624
#            True     0.738292  0.996195
# yes        False    0.622417  0.955664
#            True     0.663219  0.968703

# %%
sampled_consistency_df.groupby(["molmo_code", "rotation"])[
    "molmo_nli_avg_contrad"
].describe()
# Out:
#                      count      mean       std       min       25%       50%  \
# molmo_code rotation
# no         False      52.0  0.558225  0.211671  0.073967  0.432351  0.529586
#            True       48.0  0.686460  0.151287  0.344008  0.596239  0.704218
# yes        False      72.0  0.505393  0.203910  0.072933  0.378091  0.484316
#            True       28.0  0.519788  0.193626  0.208638  0.388456  0.473555
#
#                           75%       max
# molmo_code rotation
# no         False     0.711260  0.953193
#            True      0.772078  0.996195
# yes        False     0.656768  0.968703
#            True      0.657884  0.871177
